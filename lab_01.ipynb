# %% [markdown]
# # Práctica 1. Atributos de una imagen
#
# <div class="alert alert-block alert-success">
# <b>Resumen:</b> El siguiente código muestra cómo acceder a los atributos de una imagen utilizando la librería OpenCV.
# </div>
#
# ***

# %%
# Importar las librerías necesarias
import cv2

# %% [markdown]
# ## 1. Lectura de la imagen

# %%
img = cv2.imread('./images/circles.png')
assert img is not None, "la imagen no pudo ser leida, verifique la ruta"

# %% [markdown]
# ## 2. Atributos de una imagen

# %% [markdown]
# ### Shape (rows, columns, and channels)

# %%
print( img.shape )

# %% [markdown]
# ### Número de filas y de columnas

# %%
print(f'Alto: {img.shape[0]} píxeles')
print(f'Ancho: {img.shape[1]} píxeles')

# %% [markdown]
# ### Número de canales

# %%
# verificar la dimensión de la imagen
if len(img.shape) == 2:
    num_canales = 1
else:
    num_canales = img.shape[2]
    print(f'Número de canales: {num_canales}')

# %% [markdown]
# ### Tipo de dato

# %%
print(f'Tipo de dato: {img.dtype}')

# %% [markdown]
# ### Número total de píxeles

# %%
print(f'Número total de píxeles: {img.size}')

# %% [markdown]
# ### Tamaño en bytes

# %%
print(f'Tamaño de la imagen en bytes: {img.nbytes}')

# %% [markdown]
# <div style="margin: 20px 0; text-align:center;">
#   <div style="width:72%; margin:0 auto; position:relative;">
#     <hr style="border:none; height:2px; background: linear-gradient(90deg, transparent, #444, transparent);" />
#     <div style="position:absolute; left:50%; top:50%; transform:translate(-50%,-50%);
#       width:12px; height:12px; border-radius:50%;
#       background: radial-gradient(circle, #fff, #f59e0b, transparent 65);">
#     </div>
#   </div
# </div>

# %% [markdown]
# <div style="margin: 14px 0; text-align:left;">
#   <div style="display:inline-block; padding: 5px 10px; border-radius: 999px;
#     background: #e5e7eb; color:#111827; font-weight:600; letter-spacing:.2px;
#     border: 1px solid #d1d5db;">
#     Actividades
#   </div>
# </div>

# %% [markdown]
# 1. Seleccione **una imagen diferente** a la utilizada en el ejemplo anterior (formato **JPG** o **PNG**).
# Luego, utilizando **Python + OpenCV**, cargue la imagen y obtenga sus **atributos principales**.
# Finalmente, imprima en pantalla un resumen con la información obtenida.

# %%
# < -- aquí su código -->

# %% [markdown]
# 2. Cree una función en Python (usando OpenCV) que reciba la ruta de una imagen, la cargue y retorne en un diccionario sus principales atributos: ancho, alto, número de canales, dtype, valor mínimo, valor máximo y shape.

# %%
# < -- aquí su código -->
